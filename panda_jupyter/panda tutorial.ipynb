# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":["rahul", "rohit", "ritesh", "rakesh"],
    "marks": [92,34,24,17],
    "city" : ["delhi", "varansi", "kolkata", "dolakhpur"]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks       city
# 0   rahul     92      delhi
# 1   rohit     34    varansi
# 2  ritesh     24    kolkata
# 3  rakesh     17  dolakhpur

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv', index=False)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  rahul     92    delhi
# 1  rohit     34  varansi

# %%
df.tail(2)
# Out:
#      name  marks       city
# 2  ritesh     24    kolkata
# 3  rakesh     17  dolakhpur

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
dhruv= pd.read_csv(
